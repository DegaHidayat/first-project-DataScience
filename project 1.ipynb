# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

# %%
boston_dataset= load_boston() # load the data
boston = pd.DataFrame(boston_dataset.data,columns=boston_dataset.feature_names) # change to dataframe and columns=feature
boston['MEDV']=boston_dataset.target # target = MEDV
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(boston_dataset.DESCR) # about boston
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston.shape # 506 rows & 14 columns
# Out:
# (506, 14)

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.describe().round(3)
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  506.000  506.000  506.000  506.000  506.000  506.000  506.000  506.000
# mean     3.614   11.364   11.137    0.069    0.555    6.285   68.575    3.795
# std      8.602   23.322    6.860    0.254    0.116    0.703   28.149    2.106
# min      0.006    0.000    0.460    0.000    0.385    3.561    2.900    1.130
# 25%      0.082    0.000    5.190    0.000    0.449    5.885   45.025    2.100
# 50%      0.257    0.000    9.690    0.000    0.538    6.208   77.500    3.207
# 75%      3.677   12.500   18.100    0.000    0.624    6.624   94.075    5.188
# max     88.976  100.000   27.740    1.000    0.871    8.780  100.000   12.126
#
#            RAD      TAX  PTRATIO        B    LSTAT     MEDV
# count  506.000  506.000  506.000  506.000  506.000  506.000
# mean     9.549  408.237   18.456  356.674   12.653   22.533
# std      8.707  168.537    2.165   91.295    7.141    9.197
# ...

# %%
# i want to inspect the CHAS and RM with matplotlib
# %matplotlib inline

boston['CHAS'].plot(kind='hist',figsize=(4,4))
plt.show()

# %%
boston['RM'].plot(kind='hist',bins=20,figsize=(4,4))
plt.show()

# %%
corr = boston.corr().round(3) #correlation matrix
corr
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM     1.000 -0.200  0.407 -0.056  0.421 -0.219  0.353 -0.380  0.626  0.583
# ZN      -0.200  1.000 -0.534 -0.043 -0.517  0.312 -0.570  0.664 -0.312 -0.315
# INDUS    0.407 -0.534  1.000  0.063  0.764 -0.392  0.645 -0.708  0.595  0.721
# CHAS    -0.056 -0.043  0.063  1.000  0.091  0.091  0.087 -0.099 -0.007 -0.036
# NOX      0.421 -0.517  0.764  0.091  1.000 -0.302  0.731 -0.769  0.611  0.668
# RM      -0.219  0.312 -0.392  0.091 -0.302  1.000 -0.240  0.205 -0.210 -0.292
# AGE      0.353 -0.570  0.645  0.087  0.731 -0.240  1.000 -0.748  0.456  0.506
# DIS     -0.380  0.664 -0.708 -0.099 -0.769  0.205 -0.748  1.000 -0.495 -0.534
# RAD      0.626 -0.312  0.595 -0.007  0.611 -0.210  0.456 -0.495  1.000  0.910
# TAX      0.583 -0.315  0.721 -0.036  0.668 -0.292  0.506 -0.534  0.910  1.000
# PTRATIO  0.290 -0.392  0.383 -0.122  0.189 -0.356  0.262 -0.232  0.465  0.461
# ...

# %%
# RM is better choice for predicting MEDV

boston.plot(kind='scatter',x='RM',y='MEDV',grid=True,figsize=(8,6));

# %%
# now, i instantiating the model with Linear Regression

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# determine the feature and target
# then i make train-test split
X = boston[['RM']]
y = boston['MEDV']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 1)
# (152, 1)
# (354,)
# (152,)

# %%
# fitting the model
# this method used for find the coefficients (intercept and slope)
model.fit(X_train,y_train)

print(model.intercept_)
print(model.coef_)
# Out:
# -30.571032410898315
# [8.46109164]

# %%
# predictions
# formula: y = b+m*x where b is the estimated intercept and m is slope
# so, when the average number of rooms per dwelling is 8.5, the model predicts a home value of $41.348

new_RM = np.array([8.5]).reshape(-1,1) #make sure the feature are 2d
model.predict(new_RM)
# Out:
# array([41.3482465])

# %%
# visualitation
plt.scatter(X_test,y_test,label='testing data')
plt.plot(X_test,y_pred,label='predictions',linewidth=3)
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.legend(loc='upper left')
plt.show()

# %%
#evaluation with R-squared
#R-squared is between 0-100%

model.score(X_test,y_test)
# Out:
# 0.6015774471545622
